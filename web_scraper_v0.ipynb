# %%
# import packages

import pandas as pd
from pandas import DataFrame
import numpy as np

import itertools

import psycopg2
import datetime
from datetime import date

import matplotlib.pylab as plt
import warnings  

#import module

import os
import requests
from bs4 import BeautifulSoup
import json
from pandas import json_normalize
import time
from timeit import default_timer as timer

# %%
# web scraper packages


from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select


import mechanize
import cookiejar

import lxml
import lxml.etree

import bs4.element

# %%
#robots doc

# https://ui.attentivemobile.com/subscribers/crm.robots.txt

# %%
login_url = "https://ui.attentivemobile.com/signin?redir=%2F"

subscribers_url = "https://ui.attentivemobile.com/subscribers/crm"

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
#options.add_argument('--headless')
chrome_driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", options=options)
# Out:
# /var/folders/92/2qnmkckj6fngpzggl7jq8hv00000gn/T/ipykernel_94176/4004319892.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome_driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", options=options)

# %%
chrome_driver.implicitly_wait(300)
chrome_driver.get(login_url)
#chrome_driver.get(subscribers_url)

login_email = [USERNAME]
email_var = chrome_driver.find_element('id', 'email').send_keys(login_email)
wait = WebDriverWait(chrome_driver, 300)
#wait.until(EC.element_to_be_clickable((By.XPATH, "// div[contains(text(), 'Continue')]"))).click()
chrome_driver.implicitly_wait(300)
wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "picnic--c-boowNP-ibfZiHK-css"))).click()

login_pw = [PASSWORD]
pass_var = chrome_driver.find_element('id', 'password')

time.sleep(1)
chrome_driver.implicitly_wait(100)
ActionChains(chrome_driver).move_to_element(pass_var).send_keys(login_pw).perform()

#wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "picnic--c-boowNP-ikmfNDi-css")))
chrome_driver.implicitly_wait(100)
sign_in_button = chrome_driver.find_element(By.CLASS_NAME, "picnic--c-boowNP-ikmfNDi-css")

chrome_driver.implicitly_wait(300)
ActionChains(chrome_driver).move_to_element(sign_in_button).click(sign_in_button).perform()

# %%
# login_pw = [PASSWORD]'
# pass_var = chrome_driver.find_element('id', 'password')

# time.sleep(1)
# chrome_driver.implicitly_wait(100)
# ActionChains(chrome_driver).move_to_element(pass_var).send_keys(login_pw).perform()

# #wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "picnic--c-boowNP-ikmfNDi-css")))
# chrome_driver.implicitly_wait(100)
# sign_in_button = chrome_driver.find_element(By.CLASS_NAME, "picnic--c-boowNP-ikmfNDi-css")

# chrome_driver.implicitly_wait(300)
# ActionChains(chrome_driver).move_to_element(sign_in_button).click(sign_in_button).perform()

# %%
chrome_driver.get("https://ui.attentivemobile.com/subscribers/crm")
page_source = chrome_driver.page_source
chrome_driver.implicitly_wait(50)
time.sleep(2)

# %%
#chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div').text

# %%
# # table headers
# time.sleep(2)
# chrome_driver.implicitly_wait(50)
# ##table_column_names = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[2]/div/div').text

# table_column_names = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[2]/div/div[1]/div').text

# print(table_column_names)

# %%
#access the brand drop down menu


# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r12:"]'))).click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/a[1]'))).click()



########
######## ALL OF THE XPATHS FOLLOWING WILL NEED TO BE ALTERED TO FIT TO CORRECT PATH
########

#chrome_driver.find_element(By.XPATH, '//*[@id="radix-:r12:"]').text


#wait.until(EC.element_to_be_clickable((By.ID, "radix-:r4h:"))).click()

# for Meno Labs no change, comment this whole section out

# for JVN
#wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/a[1]'))).click()

# # for Rose Inc US
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/a[2]'))).click()


# # For rose inc AU
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/a[3]'))).click()

# # For Rose Inc Canada

# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/div[3]'))).click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-33-toggle-button"]'))).click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-33-item-4"]/span'))).click()

# chrome_driver.get("https://ui.attentivemobile.com/subscribers/crm")
# page_source = chrome_driver.page_source
# chrome_driver.implicitly_wait(50)


# # For Rose Inc UK
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radix-:r13:"]/div[3]'))).click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-33-toggle-button"]'))).click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-7-item-5"]'))).click()

# chrome_driver.get("https://ui.attentivemobile.com/subscribers/crm")
# page_source = chrome_driver.page_source
# chrome_driver.implicitly_wait(50)

# %%
# access the drop down menu - for the type of subscribers

wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-1-toggle-button"]'))).click()

# %%
# select eligible from the drop down number to segment for only eligible subscribers

status = "Eligible"
#wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "picnic--c-boowNP-ibfZiHK-css"))).click()

wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-1-item-1"]'))).click()

# %%
# # returns a json like structure of all the data contained on the first page of the subscriptions

# #first_page_table = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[2]/div/div[2]').text
# time.sleep(2)
# first_page_table = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]').text


# for i in range(500000):
#     start_time = timer()
#     chrome_driver.implicitly_wait(10)
#     ActionChains(chrome_driver).move_to_element(next_button).click(next_button).perform()
#     chrome_driver.get("https://ui.attentivemobile.com/subscribers/crm")
#     page_source = chrome_driver.page_source
#     stop_time = timer()
#     print(start_time - stop_time)


# #first_page_table.set_page_load_timeout(10)

# %%
# f = 1

# for f in range(500):
#     wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]'))).click()
#     f +=1

# #wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-32-toggle-button"]'))).click()

# %%
# #open the 'select date range' menu
# chrome_driver.find_element(By.XPATH, '//*[@id="downshift-73-toggle-button"]/p').click()
# wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="downshift-73-item-9"]/span'))).click()

# max_date_last_run = chrome_driver.find_element(By.XPATH,'//*[@id="radix-:r1b:"]/div/div[3]/div[1]/div[1]/div/div/div/div/input')
# max_date_last_run.clear()
# max_date_last_run.send_keys('Jul 05, 2021')

# %%
# extract the last date from the table

#last_table_row = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[10]').text
#last_row_date = last_table_row[-12:].replace(" ", "").replace(",", "")

#last_row_date

# %%
# %%time
#temp_1 = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[2]/div/div[2]/div[1]').text
#temp_df = pd.DataFrame([temp_1.split("\n")])

i = 1
j = 1
n = 1
#temp_df = pd.DataFrame(columns = ['subscribers', 'contact_1', 'contact_2', 'status', 'first_active'])

temp_list = list()
next_button = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]')
next_button_enabled = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]').is_enabled()
#wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]'))).click()


#next_button.click()
# Out:
# CPU times: user 2.88 ms, sys: 3.63 ms, total: 6.51 ms
# Wall time: 138 ms

# %%
# i = 0

# for i in range(50000000):
#     wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]'))).click()
#     i+=1
    
# print(i)

# %%
# #next_button.click()



# for i in range(500000):
#     chrome_driver.implicitly_wait(10)
#     divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')

#     chrome_driver.implicitly_wait(10)
#     divs_list = list(divs.find_elements(By.TAG_NAME, 'div'))
#     #print(divs_list, flush = True)
#     table_length = int(len(divs_list)/9)
#     print(divs.text)
#     print(table_length, flush = True)
#     for n in range(1, (table_length + 1)):
#         if next_button_enabled == True:
#             time.sleep(.25)
#             temp_loop = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[{}]'.format(str(n))).text
#             print(temp_loop, flush = True)
#             chrome_driver.implicitly_wait(10)
#             temp_list.append(temp_loop)
#             next_button.click()
#             n += 1

# %%
jvn_out_min = (i * 5) / (60)
jvn_out_hour = jvn_out_min/60
jvn_out_day = jvn_out_hour/12
jvn_out_day

# %%
# #next_button.click()



# for i in range(500000):
#     chrome_driver.implicitly_wait(10)
#     divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')

#     chrome_driver.implicitly_wait(10)
#     divs_list = list(divs.find_elements(By.TAG_NAME, 'div'))
#     #print(divs_list, flush = True)
#     table_length = int(len(divs_list)/9)
#     #print(divs.text)
#     print(table_length, flush = True)
#     for n in range(1, (table_length + 1)):
#         if next_button_enabled == True:
#             time.sleep(.25)
#             temp_loop = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[{}]'.format(str(n))).text
#             print(temp_loop, flush = True)
#             chrome_driver.implicitly_wait(10)
#             temp_list.append(temp_loop)
#             time.sleep(3)

# %% [markdown]
# //*[@id="app-container"]/div/div/div[2]/div[2]/div/div[2]

# %%
for i in range(500000):
   #for n in range (1,11):
    start_time = timer()
    chrome_driver.implicitly_wait(10)
    #time.sleep(1)
    #divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')
    divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')

    chrome_driver.implicitly_wait(10)
    divs_list = list(divs.find_elements(By.TAG_NAME, 'div'))
    table_length = int(len(divs_list)/9)
    for n in range(1, (table_length + 1)):
        try:
            if next_button_enabled == True:
                time.sleep(.25)
                temp_loop = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[{}]'.format(str(n))).text
                last_page_row = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[10]').text
                last_page_date = last_page_row[-12:].replace(" ", "").replace(",", "")
                chrome_driver.implicitly_wait(10)
                temp_list.append(temp_loop)
                temp_df = pd.DataFrame(temp_list)
                temp_df = temp_df[0].str.split("\n", expand = True)
                n += 1
                if n == (table_length + 1):
                    time.sleep(.25)
                    chrome_driver.implicitly_wait(20)
                    if n < 9:
                        time.sleep(.25)
                    else:
                        stop_time = timer()
                        print(n, (stop_time-start_time), flush = True)
                        WebDriverWait(chrome_driver, 10)
                        ActionChains(chrome_driver).move_to_element(next_button).click(next_button).perform()
                        #chrome_driver.implicitly_wait(20)
                        #time.sleep(.5)
                        #stop_time = timer()
                        #print(stop_time, flush = True)
                    #wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]'))).click()
                        n = 1
                        i+=1
                        if i%30 == 0:
                            #temp_df.to_csv('rose_eligible_{}_{}.csv.'.format(str(i), str(last_page_date)))
                            #chrome_driver.refresh()
                            time.sleep(.5)
        except Exception as e:
            #temp_df.to_csv('jvn_eligible_{}_{}.csv.'.format(str(i), str(last_page_date)))
            #chrome_driver.refresh()
            #time.sleep(.25)
            print(e)
            next_button.click()
            continue
            pass
# Out:
# 11 3.807120457990095
# 11 3.5837677500676364
# 11 3.653029707958922
# 11 3.8976664999499917
# 11 3.3801742081996053
# 11 3.478517583105713
# 11 3.475057124858722
# 11 3.4569701661821455
# 11 3.5530873748939484
# 11 3.4637855829205364
# 11 3.4133665829431266
# 11 3.4681769590824842
# 11 3.4794082909356803
# 11 3.481565458001569
# 11 3.478600790956989
# 11 3.6081352080218494
# 11 3.4246606670785695
# 11 3.482300375122577
# 11 3.459793916903436
# 11 3.569535625167191
# 11 3.4912533750757575
# 11 3.5152631669770926
# 11 3.5225422501098365
# 11 3.4628500409889966
# 11 3.541322832927108
# 11 3.4957408339250833
# 11 3.577179125044495
# 11 3.5783577079419047
# 11 3.542535583022982
# 11 3.5498427499551326
# 11 3.599059541011229
# 11 3.5382544158492237
# 11 3.544628999894485
# 11 3.5738042080774903
# 11 3.578639500075951
# 11 3.541302374796942
# 11 3.545791249955073
# 11 3.507268707966432
# 11 3.5457068330142647
# 11 3.565247666090727
# 11 3.5409159169066697
# 11 3.562194708036259
# ...

# %% [markdown]
# Optimize into above block
#
# 1. Batch for every 5,000 save to output file
#     a. Output file should be name recursively based on the min and max date in output
# 2. Add refresh function after the output file is saved
#     a. After refresh button, add an time.sleep(2)
#     b. After add time, add a wait.until. for next button visibility

# %%
#temp_df.to_csv('roseinc_opt_out_extra3_.csv')

temp_df.to_csv('meno_opt_out_last_.csv')

#jan31

# %%
for i in range(500000):
   #for n in range (1,11):
    start_time = timer()
    chrome_driver.implicitly_wait(10)
    #time.sleep(1)
    #divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')
    divs = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]')

    chrome_driver.implicitly_wait(10)
    divs_list = list(divs.find_elements(By.TAG_NAME, 'div'))
    table_length = int(len(divs_list)/9)
    for n in range(1, (table_length + 1)):
        try:
            if next_button_enabled == True:
                time.sleep(.25)
                temp_loop = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[{}]'.format(str(n))).text
                last_page_row = chrome_driver.find_element(By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[3]/div/div[2]/div[10]').text
                last_page_date = last_page_row[-12:].replace(" ", "").replace(",", "")
                chrome_driver.implicitly_wait(10)
                temp_list.append(temp_loop)
                temp_df = pd.DataFrame(temp_list)
                temp_df = temp_df[0].str.split("\n", expand = True)
                n += 1
                if n == (table_length + 1):
                    time.sleep(.25)
                    chrome_driver.implicitly_wait(20)
                    if n < 9:
                        time.sleep(.25)
                    else:
                        stop_time = timer()
                        print(n, (stop_time-start_time), flush = True)
                        WebDriverWait(chrome_driver, 10)
                        ActionChains(chrome_driver).move_to_element(next_button).click(next_button).perform()
                        #chrome_driver.implicitly_wait(20)
                        #time.sleep(.5)
                        #stop_time = timer()
                        #print(stop_time, flush = True)
                    #wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="app-container"]/div/div/div[2]/div[4]/div/div/button[2]'))).click()
                        n = 1
                        i+=1
                        if i%30 == 0:
                            #temp_df.to_csv('rose_ca_eligible_{}_{}.csv.'.format(str(i), str(last_page_date)))
                            #chrome_driver.refresh()
                            time.sleep(.5)
        except Exception as e:
            #temp_df.to_csv('jvn_eligible_{}_{}.csv.'.format(str(i), str(last_page_date)))
            #chrome_driver.refresh()
            #time.sleep(.25)
            print(e)
            next_button.click()
            continue
            pass

# %% [markdown]
# Make the edits to the output to match the format of the Pipette final list.
#
# 1. Final Output should be of the formation Profile Name, Phone Number, Email Address, and Signup Date
# 2. Remove all rows without a phone number
# 3. Remove all rows without an email address
# 4. De-duplicate across final 4 column sheet
# 5. Do the same process with those that are opted out, and de_duplicate across both shets.

# %%
temp_df.tail(10)

# %%
# load all of the csv's into pandas dataframes

# %%
#merge all dataframes into singular dataframe




# rename the dataframes to c("identifier_1", "identifier_2", "identifier_3", "eligibility", "signup_date")
# these columns will be further renamed later on

# %%
#alter the merged dataframe according to these parameters

# %%
# remove all rows without both a phone number and an email address
# in one of the first three rows

# %%
# dedupliate across the merged dataset

# %%
#do the same process for those that were opted out and depuplicate across the
